# %% [markdown]
# # DNN: analysis with Keras of 2D data

# %% [markdown]
# # Components of the group 2503

# %% [markdown]
# - Marco Boscolo&emsp;&emsp;&emsp;2157559
# - Francesco La Rovere&nbsp; 2164968
# - Nicolò Montagner&emsp;&ensp; 2165809
# - Raffaele Sabatini&emsp;&emsp; 2165739

# %% [markdown]
# # Importing libraries and packeges

# %%
import numpy as np #Always usefull and to be used
from copy import deepcopy

import keras
import tensorflow.random as tf_r
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras import layers
import keras_tuner
# Added to visualize the confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns

import matplotlib as mpl
import matplotlib.pyplot as plt

from useful import *


# default font
plt.rcParams['font.size'] = 13

# %run useful.py

# training data
perc_train = 0.8

# %% [markdown]
# # Defining useful functions

# %% [markdown]
# We modify a bit the funcions of the given notebook in order to use them multiple times in the notebook.
# We also add the function to compute and plot the confusion matrix.
# The reduce function is in this section because with "reduce_rate=1" it just split the dataset in training and validation/test sets.

# %%
# Show the result of a model along the projection on the first 2 components (the relevant ones)
def PlotPrediction(x, y, xM, xS, Model, whichData, whichModel):

    L = 8
    B = 10

    dX = .05
    X1 = np.arange(0, 10+dX, dX)
    LG = len(X1)
    X, Y = np.meshgrid(X1, X1)
    allXY = np.reshape((np.array((X,Y)).T), (LG**2,2))
    grid = np.random.rand(LG**2, L)*B
    grid[:,:2] = allXY
    grid_r = Standardize(grid, xM, xS)

    pred = Model.predict(grid_r)

    fig, AX = plt.subplots(1, 3, figsize = (18,6))
    fig.suptitle(f"Prediction with {whichModel} model", fontsize = 20)

    ax = AX[0]
    ax.scatter(x[:,0], x[:,1], c=y, s=6)
    ax.set_title(f"{whichData} data", fontsize = 12)

    ax = AX[1]
    ax.pcolormesh(X1,X1,pred.reshape((LG, LG)))
    ax.set_title("prediction $\\hat y$")

    ax = AX[2]
    pred01=np.copy(pred)
    pred01[pred>0.5]=1
    pred01[pred<=0.5]=0
    ax.pcolormesh(X1,X1,pred01.reshape((LG, LG)))
    ax.set_title("Where $\\hat y > 1/2$")

    #print(f"remember: these are 2 out of L={L} dimensions, of which L-2 contain random noise")

    plt.show()

# %%
# For a specific model plot the graph of accuracy and loss of the training and the validation/test set
def PlotAccuracyAndLoss(fit, whichData, whichModel):

    fig, AX = plt.subplots(1, 2, figsize = (16,8))

    fig.suptitle(f"Performance of the {whichModel} model over {whichData} data")

    ax = AX[0]
    ax.plot(fit.history['accuracy'], label="train", c="b", ls="--")
    ax.plot(fit.history['val_accuracy'], label="valid.", c="r")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Accuracy")
    ax.legend()

    ax = AX[1]
    ax.plot(fit.history['loss'],label="train",c="b",ls="--")
    ax.plot(fit.history['val_loss'],label="valid.",c="r")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Loss")
    ax.legend()

    plt.show()

# %%
# Plot the confusion matrix of a model
def plot_conf_matrix(x_valid,y_valid,Model,whichModel):
    # Compute the prediction
    y_pred = Model.predict(x_valid)
    y_pred = (y_pred > 0.5).astype(int)

    # Compute the confusion matrix
    conf_matrix = confusion_matrix(y_valid, y_pred, normalize='all')

    # Plot the confusion matrix
    plt.figure(figsize=(5., 5.))
    sns.heatmap(conf_matrix, annot=True, cmap="YlGnBu", fmt=".2f")

    plt.title(f"Confusion matrix of {whichModel} model over test set")
    plt.xlabel("Predicted label")
    plt.ylabel("True label")

    plt.tight_layout()
    plt.show()
    plt.close()

# %%
# Define the function to split the dataset into trainig and test sets
def Split_Train_Test(x, y, perc_train):

    N = len(x)
    indeces = np.arange(N)
    np.random.shuffle(indeces)
    x = x[indeces]
    y = y[indeces]

    N_train = int(perc_train * N)

    (x_train, y_train) = (x[0 : N_train], y[0 : N_train])
    (x_test , y_test)  = (x[N_train : ] , y[N_train : ])
    print("Original: ", len(x), "\t Train: ", len(x_train), "\t Test: ", len(x_test))

    return x_train, y_train, x_test, y_test

# %% [markdown]
# # Get the data and pre-processing

# %% [markdown]
# #### Read data

# %%
# Keras works with numpy arrays: just use them from the start
TYPE = 3

# data point size
L = 8
# span of each component
B = 10
x = np.loadtxt(filename("data",L,TYPE), delimiter=' ')
y = np.loadtxt(filename("labels",L,TYPE), delimiter=' ')
y = y.astype("int")
print(x.shape)
N = len(x)
# average and std.dev.
x_mean = np.mean(x, axis=0)
x_std  = np.std(x, axis=0)

# dim. of a sample
L = len(x[0])
print(L)

'''
for i in range(5):
    print(x[i],y[i])
'''

N_train = int(perc_train * N)
print(f'data: {N}\ntrain: {N_train} \n')

print("Input Data here below:")
plot_data(x,y)
# Out:
# (2000, 8)
# 8
# data: 2000
# train: 1600
#
# Input Data here below:

# %% [markdown]
# ATTENTION: Recall that the chart above is the projection on the dataset just along the first and the second components/coordinates.

# %% [markdown]
# #### Standardize data

# %%
print("Before rescaling:\nMean value =", x_mean,"\nStd dev = ", x_std)
x = Standardize(x, x_mean, x_std)
print("After rescaling:\nMean value =", x.mean(axis=0), "\nStd dev =", x.std(axis=0))
# Out:
# Before rescaling:
# Mean value = [5.01860571 5.01726228 5.02153857 5.08947968 5.10248206 5.03670082
#  4.88645281 5.05411547]
# Std dev =  [2.86912607 2.89535235 2.87312372 2.86324409 2.90278676 2.91948328
#  2.92549254 2.89281292]
# After rescaling:
# Mean value = [ 2.53633226e-15  9.27924404e-16 -1.44884105e-15 -2.38371996e-15
#  -2.85274582e-15 -2.02196593e-15 -1.09010023e-15 -1.53632662e-15]
# Std dev = [1. 1. 1. 1. 1. 1. 1. 1.]

# %% [markdown]
# #### Split training and test data

# %%
(x_train, y_train) = (x[0 : N_train], y[0 : N_train])
(x_valid, y_valid) = (x[N_train : ], y[N_train : ])
print("Train: ", len(x_train), "\t Test: ", len(x_valid))
# Out:
# Train:  1600 	 Test:  400

# %% [markdown]
# # The original model

# %% [markdown]
# The three example models present in the starting jupyther notebook (we show the result just for the first model with 3 layers composed be 20 neurons each).

# %% [markdown]
# #### Define the model with Keras / Tensorflow

# %%
# reproducibility (?)
np.random.seed(12345)
tf_r.set_seed(12345)

# We use case 1
CASE = 1

if CASE == 1:
    OriginalModel = Sequential()
    OriginalModel.add(Dense(L,input_shape=(L,),activation='relu'))
    OriginalModel.add(Dense(20,activation='relu'))
    OriginalModel.add(Dropout(0.1))
    OriginalModel.add(Dense(20,activation='relu'))
    OriginalModel.add(Dropout(0.1))
    OriginalModel.add(Dense(20,activation='relu'))
    OriginalModel.add(Dropout(0.1))
    OriginalModel.add(Dense(1,activation='sigmoid')) #sigmoid because we want a result between 0 and 1
    nepoch = 500
# as case 1 but one layer shorter
if CASE == 2:
    OriginalModel = Sequential()
    OriginalModel.add(Dense(L,input_shape=(L,),activation='relu'))
    OriginalModel.add(Dense(40,activation='relu'))
    OriginalModel.add(Dropout(0.1))
    OriginalModel.add(Dense(20,activation='relu'))
    OriginalModel.add(Dropout(0.1))
    OriginalModel.add(Dense(1,activation='sigmoid'))
    nepoch = 400
#deeper
if CASE == 3:
    OriginalModel = Sequential()
    OriginalModel.add(Dense(L,input_shape=(L,),activation='relu'))
    OriginalModel.add(Dense(10,activation='relu'))
    OriginalModel.add(Dense(10,activation='relu'))
    OriginalModel.add(Dense(10,activation='relu'))
    OriginalModel.add(Dense(10,activation='relu'))
    OriginalModel.add(Dense(10,activation='relu'))
    OriginalModel.add(Dense(10,activation='relu'))
    OriginalModel.add(Dense(1,activation='sigmoid'))
    nepoch = 400

print(OriginalModel.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # reproducibility (?)
# ----> 2 np.random.seed(12345)
#       3 tf_r.set_seed(12345)
#       5 # We use case 1
#
# NameError: name 'np' is not defined

# %% [markdown]
# #### Optimization method and cost function

# %%
OriginalModel.compile(loss='binary_crossentropy', optimizer='RMSprop', #optimizer='adam',
              metrics=['accuracy'])

# %% [markdown]
# #### Training

# %%
fit = OriginalModel.fit(x_train, y_train, epochs = nepoch, batch_size = 50, validation_data = (x_valid,y_valid), verbose=0)

# %% [markdown]
# #### Accuracy and Loss

# %%
PlotAccuracyAndLoss(fit, whichData="input", whichModel="original")

# %% [markdown]
# #### Show predictions

# %%
# Cause now the model is trained, after the calling the fit method
PlotPrediction(x,y,x_mean,x_std,OriginalModel,whichData="Input all",whichModel="original")
# Out:
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 164us/step

# %% [markdown]
# #### Confusion Matrix

# %%
plot_conf_matrix(x_valid, y_valid, OriginalModel,"original")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step

# %% [markdown]
# # Search for best hyperparameters (hence model)

# %% [markdown]
# #### Implementing the Random Search
#
# We implement a random search using **keras_tuner** in order to find the best hyperparameters of the model. <br>
# We try over 40 possibile models with 1 trial execution each, more models tried would have been better and also more then one execution for model but that would have required too much computational time. <br>
# The space of hyperparameters is composed by the following:
# - Layers of the model:&emsp;&nbsp;from 1 to 6
# - Neurons of the model:&nbsp; from 10 to 30 with steps of 5
# - Activation functions:&emsp;&nbsp;ReLU, sigmoid, tanh, elu
# - Optimizers:&emsp;&emsp;&emsp;&emsp;&emsp;&nbsp;ADAM, RMSprop, SGD
# - Dropout values:&emsp;&emsp;&emsp;&ensp;0, 0.1, 0.2
# - Learning rates:&emsp;&emsp;&emsp;&ensp;&nbsp;from 10e-6 to 10e-1

# %%
#We start by building the model with the list of hyperparameters listed above
def build_model(hp):

    model = keras.Sequential()
    model.add(Dense(8,input_shape=(8,),activation='relu'))
    # Tune the number of layers of the model
    for i in range(hp.Int("num_layers", 1, 6)):
        #print(f"Adding hidden layer {i} with {hp.Int(f'units_{i}', 10, 30, step=5)} units")  # Debug print
        model.add(layers.Dense(
                #Define the units and the activation functions
                units=hp.Int(f"units_{i}", min_value=10, max_value=30, step=5),
                activation=hp.Choice("activation", ["relu", "sigmoid", "tanh", "elu"]),
            )
        )
        #Define the dropout values of the model
        model.add(layers.Dropout(rate=hp.Float("dropout", min_value = 0, max_value = 0.2, step = 0.05)))

    #Output layer is composed by 1 neuron since it's classification task
    model.add(layers.Dense(1, activation="sigmoid"))

    #Define the learning rate of the model
    learning_rate = hp.Float("lr", min_value=1e-6, max_value=1e-1, sampling="log")
    model.compile(

        #Define the optimizers of the model
        optimizer=hp.Choice("optimizer", ["adam", "RMSprop", "SGD"]), loss="binary_crossentropy",
        metrics=["accuracy"])
    return model


#build_model(keras_tuner.HyperParameters())

#After builiding the model we impose the tuning
tuner = keras_tuner.RandomSearch(
    hypermodel = build_model,
    objective = "val_accuracy",
    max_trials = 40,
    executions_per_trial = 1,
    overwrite = True,
)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# #### Actual search for the best hyperparameters

# %% [markdown]
# The space of hyperparameters in which we search the best mode is the following.

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 6
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 6, 'step': 1, 'sampling': 'linear'}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 10, 'max_value': 30, 'step': 5, 'sampling': 'linear'}
# activation (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'sigmoid', 'tanh', 'elu'], 'ordered': False}
# dropout (Float)
# {'default': 0.0, 'conditions': [], 'min_value': 0.0, 'max_value': 0.2, 'step': 0.05, 'sampling': 'linear'}
# lr (Float)
# {'default': 1e-06, 'conditions': [], 'min_value': 1e-06, 'max_value': 0.1, 'step': None, 'sampling': 'log'}
# optimizer (Choice)
# {'default': 'adam', 'conditions': [], 'values': ['adam', 'RMSprop', 'SGD'], 'ordered': False}

# %% [markdown]
# And here we search.

# %%
nEpochs = 300
tuner.search(x_train, y_train, batch_size = 50, epochs = nEpochs, validation_data=(x_valid, y_valid), verbose=1)
# Out:
# Trial 40 Complete [00h 00m 11s]
# val_accuracy: 0.9700000286102295
#
# Best val_accuracy So Far: 0.9725000262260437
# Total elapsed time: 00h 07m 19s

# %% [markdown]
# #### Summary of the searching results

# %%
# Printing out the 4 best models found by the keras tuner
tuner.results_summary(num_trials=4)

#There are always created 5 units because even if the hidden layers are tuned as 1 or 2 or... the dropout layers are always 
#created. Tho they are not used
# Out:
# Results summary
# Results in ./untitled_project
# Showing 4 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 33 summary
# Hyperparameters:
# num_layers: 2
# units_0: 25
# activation: sigmoid
# dropout: 0.0
# lr: 0.04074813995371103
# optimizer: adam
# units_1: 30
# units_2: 30
# units_3: 10
# units_4: 15
# units_5: 30
# Score: 0.9725000262260437
#
# Trial 39 summary
# Hyperparameters:
# num_layers: 3
# units_0: 10
# activation: relu
# dropout: 0.0
# lr: 0.06812666525363129
# optimizer: adam
# units_1: 10
# units_2: 30
# units_3: 10
# units_4: 10
# units_5: 25
# Score: 0.9700000286102295
#
# Trial 16 summary
# Hyperparameters:
# num_layers: 3
# units_0: 30
# activation: tanh
# dropout: 0.0
# lr: 0.0022647871132353693
# optimizer: RMSprop
# units_1: 15
# units_2: 30
# units_3: 20
# units_4: 10
# units_5: 15
# Score: 0.9674999713897705
#
# Trial 28 summary
# Hyperparameters:
# num_layers: 2
# units_0: 30
# activation: elu
# dropout: 0.1
# ...

# %% [markdown]
# #### Considering 4 best models

# %% [markdown]
# We take the best 4 models obtained with that specific training and test sets.

# %%
#The tuner returns the model already trained, and we take the 4 best ones
#models = tuner.get_best_models(num_models=4)

modelsHyperParam = tuner.get_best_hyperparameters(num_trials = 4)

# %% [markdown]
# ## K-fold cross validation

# %% [markdown]
# We perform a K-fold cross validation to compare the best 4 models obtained on that spacific training set. <br>
# We take the training set and we devide it in k-part, each time using one part as validation and all the others as training, and finally we average out the results obtained. <br>
# The following function is the one we use for this task.

# %%
# Function to perform the K-fold cross validation
# Take as input a model and it returns
# train_accuracy , val_accuracy , train_loss , val_loss
def k_fold_cross_validation(x_train, y_train, modelsHyperParam, k, epoch_kfold, batch_kfold) :

    xtrain = np.array(x_train)
    ytrain = np.array(y_train)

    train_accuracy = np.zeros(shape=epoch_kfold)
    val_accuracy   = np.zeros(shape=epoch_kfold)
    train_loss     = np.zeros(shape=epoch_kfold)
    val_loss       = np.zeros(shape=epoch_kfold)

    # Divide training set in K folds
    x_folds = []
    y_folds = []
    index = np.arange(x_train.shape[0])
    np.random.shuffle(index)
    x_train = x_train[index,:]
    y_train = y_train[index]

    for i in range(k) :
        x_folds.append(x_train[i::k])
        y_folds.append(y_train[i::k])

    # Train and validate
    for test in range(k):

        x_train_fold = [x for i, x in enumerate(x_folds) if i != test]
        y_train_fold = [x for i, x in enumerate(y_folds) if i != test]

        x_train_fold = np.concatenate(x_train_fold)
        y_train_fold = np.concatenate(y_train_fold)

        x_validate_fold = x_folds[test]
        y_validate_fold = y_folds[test]



        #fit_kfold = model.fit(x_train_fold , y_train_fold, epochs = epoch_kfold, batch_size = batch_kfold, 
        # validation_data = (x_validate_fold,y_validate_fold), verbose=1)
        model = build_model(modelsHyperParam)
        fit_kfold = model.fit(x_train_fold , y_train_fold, epochs = epoch_kfold, batch_size = batch_kfold, 
                              validation_data = (x_validate_fold,y_validate_fold), verbose=0)

        train_accuracy = train_accuracy + fit_kfold.history['accuracy']
        val_accuracy   = val_accuracy   + fit_kfold.history['val_accuracy']
        train_loss     = train_loss     + fit_kfold.history['loss']
        val_loss       = val_loss       + fit_kfold.history['val_loss']


    train_accuracy = train_accuracy/k
    val_accuracy   = val_accuracy/k
    train_loss     = train_loss/k
    val_loss       = val_loss/k

    return train_accuracy, val_accuracy, train_loss, val_loss

# %% [markdown]
# Applying the k-fold cross validation to the 4 best models obtained.
# We split the training set in k=5 fold.

# %%
# The four array which will contain the results for the 4 best models
train_accuracy = []
val_accuracy   = []
train_loss     = []
val_loss       = []

num_k = 5
nEpochs = 300
#num_batch = int( len(x_train)/(num_k*10) )
num_batch = 50
#set the batch size as 1/10 ok a k-fold set, should be somethin like 25/30

for i in range(len(modelsHyperParam)):
    tr_acc , vl_acc, tr_loss, vl_loss = k_fold_cross_validation(x_train, y_train, modelsHyperParam[i], k=num_k, epoch_kfold=nEpochs, batch_kfold=num_batch)
    train_accuracy.append(tr_acc)
    val_accuracy.append  (vl_acc)
    train_loss.append    (tr_loss)
    val_loss.append      (vl_loss)

# %% [markdown]
# #### Results of the k-fold

# %% [markdown]
# Showing the performance obtained from the k-fold validation onto the 4 best models, the first in the top to the fourth in the bottom.

# %%
for i in range(len(modelsHyperParam)):

  fig, AX = plt.subplots(1, 2, figsize = (12,6))
  fig.suptitle(f"Performance of the model N°{i+1}")

  ax = AX[0]
  ax.plot(train_accuracy[i], label="train" , c="b", ls="--")
  ax.plot(val_accuracy[i]  , label="valid.", c="r")
  ax.set_xlabel('epoch')
  ax.set_ylabel("Accuracy")
  ax.legend()

  ax = AX[1]
  ax.plot(train_loss[i],label="train" ,c="b",ls="--")
  ax.plot(val_loss[i]  ,label="valid.",c="r")
  ax.set_xlabel('epoch')
  ax.set_ylabel("Loss")
  ax.legend()

  fig.tight_layout()
  plt.show()

  print("\n")

# %% [markdown]
# #### Choice and train of the best model
#
# As we can see the model with the best accuracy is the first one.

# %%
best_Hyperparameters = 0

# %% [markdown]
# We show the structure of this model, we train it using now the whole training set and an we plot its accuracy, loss and confusion matrix over the original test set.

# %%
#setting the chosen model as the best one
Hyperparam = modelsHyperParam[best_Hyperparameters]

best_model = build_model(Hyperparam)

#We retrain the best model using the whole training set
fit_best = best_model.fit(x_train, y_train, epochs=350, batch_size=50, validation_data = (x_valid, y_valid), verbose=0)
#showing the structure of the best model
best_model.summary()
# Out:
# Model: "sequential_26"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_119 (Dense)               │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_120 (Dense)               │ (None, 25)             │           225 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_67 (Dropout)            │ (None, 25)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_121 (Dense)               │ (None, 30)             │           780 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_68 (Dropout)            │ (None, 30)             │             0 │
# ...

# %% [markdown]
# From the below graphs we notice that despite the precautions taken the best model soffers of overfitting.

# %%
PlotAccuracyAndLoss(fit_best, "input", "best")

# %%
PlotPrediction(x, y, x_mean, x_std, best_model, "Input all" ,"best")
# Out:
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 206us/step

# %% [markdown]
# #### Confusion Matrix

# %% [markdown]
# We show the confusion matrix onto the test set to check how our best model performs. <br>
# A confusion matrix underlines the differences between predicted labels and true labels, to be more specific in this binary classification case we have:
# * True Positive &emsp;(TP) : predicted label 1, true label 1
# * True Negative &ensp;(TN) : predicted label 0, true label 0
# * False Positive &ensp;(FP) : predicted label 1, but true label 0
# * False Negative (FN) : predicted label 0, but true label 1
#
# And we recall that the accuracy is corrected guesses / number of total data, so in this case is (TP+TN) / (TP+TN+FP+FN).

# %%
plot_conf_matrix(x_valid, y_valid, best_model, "best")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step

# %% [markdown]
# # Check robustness (changing dataset)

# %% [markdown]
# We use augmented data and reduce data to check the results of out best model. <br>
# So we check if our best trained model is robust to the change of the dataset, in other words we check how it behaves by changing the dataset.

# %% [markdown]
# ## Augmenting data
#
# We create new sinthetic generated dataset with bigger size starting from the training set (test set still unused and untouch so we can evaluate performaces at the end). <br>
# We used two approch:
# * We choose the nearest point in the 8 dimensional space and, accorgind to their label, we add another point with the same label. The new point is not exactly in the middle point of the previous two but the position has some noise given by a standard distribution;
# * We add same small noise to the original data using small gaussian distribution

# %% [markdown]
# #### "Linear" augumentation
# The first approch here below:

# %%
# For each point P we find the K closest points to P with same color and add M points on the segment connecting them
# For every generated point we consider the closest points to it (how many? validation_size), if the amount of mismatching labels reaches a threshold, such point isn't appended

def augment_data_linear(x_train, y_train, K=2, M=3, keep_old=True, validation_size=10):
    augmented_x = np.array([])
    augmented_y = np.array([])

    if keep_old:
        augmented_x=x_train
        augmented_y=y_train

    for i in range( np.shape(y_train)[0] ):
        x, y = x_train[i], y_train[i]
        eq_colored_x = x_train[y_train == y]
        distances = [np.sqrt(np.sum( (x-z)**2) ) for z in eq_colored_x]

        indices = np.argsort(distances)[1:K+1] # first index is the position of x (distance of x with itself is 0)
        closest_samples = [eq_colored_x[indx] for indx in indices]

        for close_x in closest_samples:
            for _ in range(M):
                new_x = close_x + (x-close_x)*np.random.uniform() + np.random.normal(0,0.025,8)

                #Validation of the new_x point
                dist = np.array([ np.sqrt(np.sum( (new_x-p)**2 )) for p in x_train ])
                validation_indices = np.argsort(dist)[:validation_size]
                validation_labels = np.array([y_train[indx] for indx in validation_indices])

                mismatch = len(validation_labels[validation_labels != y])

                if mismatch/validation_size > 1/5:
                    continue
                else:
                    augmented_x = np.vstack([augmented_x, new_x])
                    augmented_y = np.append(augmented_y, y)

    return np.array(augmented_x), np.array(augmented_y)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

size = 50
data = np.random.random((size, 8))
dummy_labels = np.random.choice((0, 1), size=size)
#print(np.shape(data))
print("Input data size: ",len(y_train))
axes[0].scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=6)
axes[0].set_title("Input training data")

augm_data_lin, augm_labels_lin = augment_data_linear(x_train, y_train, K=3, M=3, validation_size=15)
print("Linear Augmented data size: ",len(augm_labels_lin))
#print(np.shape(augm_data))
axes[1].scatter(augm_data_lin[:, 0], augm_data_lin[:, 1], c=augm_labels_lin, s = 6)
axes[1].set_title("Augmented linear data")
# Out:
# Input data size:  1600
# Linear Augmented data size:  3178
# Text(0.5, 1.0, 'Augmented linear data')

# %%
best_EvalOnAugLin = best_model.evaluate(augm_data_lin,augm_labels_lin,batch_size=50,verbose=0,return_dict=True)
print("Accuracy of best model using weights from training with input data, on the augmented linear data is :", best_EvalOnAugLin['accuracy'])
print("Loss of best model using weights from training with input data, on the augmented linear data is :", best_EvalOnAugLin['loss'])
# Out:
# Accuracy of best model using weights from training with input data, on the augmented linear data is : 0.984581470489502
# Loss of best model using weights from training with input data, on the augmented linear data is : 0.04391080141067505

# %% [markdown]
# #### Retrain

# %% [markdown]
# If we retrain our best model onto the augmented linear data, so mantaining the structure of the NN but finding the new best weights, we find the results below.

# %%
#We build again a model with the same hyperparameters
best_model1 = build_model(Hyperparam)

#We retrain the best model using the whole training set
fit_aug_lin = best_model1.fit(augm_data_lin, augm_labels_lin, epochs=320, batch_size=50, validation_data = (x_valid, y_valid), verbose=0)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
PlotPrediction(augm_data_lin, augm_labels_lin, x_mean, x_std, best_model1, whichData = "Augmented linear", whichModel = "best (trained aug lin)")
# Out:
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 180us/step

# %%
PlotAccuracyAndLoss(fit_aug_lin, "Augmented linear", "best (trained aug lin)")

# %%
plot_conf_matrix(x_valid, y_valid, best_model1,"best (trained aug lin)")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step

# %% [markdown]
# #### Gaussian Noise
# The second approch here below:

# %%
def augment_data_gaussian(x_train, y_train, N, mu=0, sigma=0.2): # mu and sigma parameters of the noise

    len_x = x_train.shape[0]
    L = x_train.shape[1]
    print(len_x,L)
    N = max(N, len_x) #we create at least a number of data equal to the starting ones

    quot      = N // len_x
    remainder = N % len_x

    index_all = []

    # duplicating the dataset "quot" times, so we'll cover the space equally as the starting data
    for i in range(0, quot):
        index = np.arange( x_train.shape[0] )
        np.random.shuffle(index)
        index_all = np.concatenate( (index_all,index) ).astype(int)


    # finally adding the remaing part of N modulo len_x
    index  = np.arange( x_train.shape[0] )
    chosen = np.random.choice(index, size=remainder, replace=False) #if we want we can also replicate the data
    index_all = np.concatenate( (index_all,chosen) ).astype(int)

    augmented_x = []
    augmented_y = []

    for j in index_all:
        noise = np.random.normal(mu, sigma, L)
        result = np.array(x_train[j,:]) + noise
        augmented_x.append( result )
        augmented_y.append( y_train[j] )

    return np.array(augmented_x), np.array(augmented_y)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

axes[0].scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=6)
axes[0].set_title("Input training data")

# we used as std for the noise 1/20 of the avarage std (accross the L coordinates) of the data
augm_data_gauss, augm_labels_gauss = augment_data_gaussian(x_train, y_train, N=4000, mu=0, sigma=np.mean(np.std(x_train, axis=0))/20)

axes[1].scatter(augm_data_gauss[:, 0], augm_data_gauss[:, 1], c=augm_labels_gauss, s = 6)
axes[1].set_title("Augmented gauss data")
# Out:
# 1600 8
# Text(0.5, 1.0, 'Augmented gauss data')

# %%
best_EvalOnAugGauss = best_model.evaluate(augm_data_gauss,augm_labels_gauss,batch_size=50,verbose=0,return_dict=True)
print("Accuracy of best model using weights from training with input data, on the augmented gauss data is :", best_EvalOnAugGauss['accuracy'])
print("Loss of best model using weights from training with input data, on the augmented gauss data is :", best_EvalOnAugGauss['loss'])
# Out:
# Accuracy of best model using weights from training with input data, on the augmented gauss data is : 0.8017500042915344
# Loss of best model using weights from training with input data, on the augmented gauss data is : 0.40425485372543335

# %% [markdown]
# #### Retrain

# %% [markdown]
# If we retrain our best model onto the augmented linear data, so mantaining the structure of the NN but finding the new best weights, we find the results below.

# %%
best_model2 = build_model(Hyperparam)

#We retrain the best model using the whole training set
fit_aug_gauss = best_model2.fit(augm_data_gauss, augm_labels_gauss, epochs=250, batch_size=50, validation_data = (x_valid, y_valid), verbose=0)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
PlotPrediction(augm_data_gauss, augm_labels_gauss, x_mean, x_std, best_model2, whichData = "Augmented gauss", whichModel = "best (trained aug gauss)")
# Out:
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 182us/step

# %%
PlotAccuracyAndLoss(fit_aug_gauss, "Augmented gauss", "best (trained aug gauss)")

# %%
plot_conf_matrix(x_valid, y_valid, best_model2,"best (trained aug gauss)")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step

# %% [markdown]
# ## Reduced sample
#
# From the starting sample we create a reduce dataset. <br>
# We achieve this by choising randomly a fraction of the all data, which can be done with or without replacement (i.e. the possibility of taking multiple copies of one specific data).

# %%
# Define the function to produce the reduced set
def reduce_sample(x, y, reduce_rate=1, replace = False):
    n_reduced = int(reduce_rate* len(x))
    indices = np.random.choice(len(x), size=n_reduced, replace=replace)
    x_reduced = x[indices]
    y_reduced = y[indices]

    # average and std.dev. of the reduced dataset
    x_reduced_mean = np.mean(x_reduced, axis=0)
    x_reduced_std  = np.std (x_reduced, axis=0)

    x_reduced = Standardize(x_reduced, x_reduced_mean, x_reduced_std)

    print("Input: ", len(x), "\t Reduced: ", len(x_reduced))

    return x_reduced, y_reduced

# %%
x_reduced, y_reduced = reduce_sample(x_train,y_train,reduce_rate=0.75,replace=True)
# Out:
# Input:  1600 	 Reduced:  1200

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

axes[0].scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=6)
axes[0].set_title("Input training data")

axes[1].scatter(x_reduced[:, 0], x_reduced[:, 1], c=y_reduced, s=6)
axes[1].set_title("Reduced data")
# Out:
# Text(0.5, 1.0, 'Reduced data')

# %%
best_EvalOnReduced = best_model.evaluate(x_reduced,y_reduced,batch_size=50,verbose=0,return_dict=True)
print("Accuracy of best model using weights from training with input data, on the reduced data is :", best_EvalOnAugLin['accuracy'])
print("Loss of best model using weights from training with input data, on the areduced data is :", best_EvalOnAugLin['loss'])
# Out:
# Accuracy of best model using weights from training with input data, on the reduced data is : 0.984581470489502
# Loss of best model using weights from training with input data, on the areduced data is : 0.04391080141067505

# %% [markdown]
# #### Retraining

# %% [markdown]
# If we retrain our best model onto the reduced data, so mantaining the structure of the NN but finding the new best weights, we find the results below.

# %%
#we create a deepcopy so the weights in "best_model" stay unchanged
best_model3 = build_model(Hyperparam)

#We retrain the best model using the whole training set
fit_reduced = best_model3.fit(x_reduced,y_reduced, epochs=450, batch_size=50, validation_data = (x_valid, y_valid), verbose=0)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
PlotPrediction(x_reduced,y_reduced,x_mean,x_std,best_model3,whichData="Reduced",whichModel="best (trained reduced)")
# Out:
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 179us/step

# %%
PlotAccuracyAndLoss(fit_reduced, "Reduced", "best (trained reduced)")

# %%
plot_conf_matrix(x_valid, y_valid, best_model3,"best (trained reduced)")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step

# %% [markdown]
# # Conclusions

# %% [markdown]
# Looking at the data we assume that our model is overfitting, as the validation loss increases significantly at higher epochs. Implementing the Early Stopping algorithm would likely mitigate this issue. From a qualitative point of view we can look at the prediction charts, where the bulk of the dataset is correctly classified, but there are blurry areas at the edges, as we expected.
# Also from a quantitative side by the mean of the confusion matrices and the value of the test accuracy and test loss, we can say the model perfoms quite good in particular in the data augmented with the gaussian method.
#
# As expected the model trained with less data perform a qualitative worst prediction of the expected data.
