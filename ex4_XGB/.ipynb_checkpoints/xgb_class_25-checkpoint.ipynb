# %%
from joblib import Parallel, delayed
import json
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import tensorflow as tf
from tensorflow import keras
from keras import layers
import keras_tuner
import seaborn as sns
from tqdm import tqdm
import pandas as pd
from scipy.stats import ttest_ind
from sklearn.model_selection import GridSearchCV
from sklearn.utils import shuffle
from sklearn.model_selection import KFold, train_test_split, StratifiedKFold, cross_val_score
from scikeras.wrappers import KerasClassifier
# AdaBoost Algorithm
from sklearn.ensemble import AdaBoostClassifier
# Gradient Boosting 
from sklearn.ensemble import GradientBoostingClassifier
# XGBoost 
import xgboost
from xgboost import XGBClassifier
from xgboost import plot_importance, to_graphviz, plot_tree
print("XGBoost version:",xgboost.__version__)

mycmap = "winter"
mpl.rcParams['image.cmap'] = mycmap
plt.rcParams['font.size'] = 13
# Out:
# XGBoost version: 3.0.0

# %%
np.random.seed(12345)

dname="./DATA/"
str0="_XGB_25.dat"
fnamex=dname+'x'+str0
fnamey=dname+'y'+str0
x = np.loadtxt(fnamex, delimiter=" ",dtype=float)
y = np.loadtxt(fnamey)
y = y.astype(int)
N,L = len(x), len(x[0])

N_train = int(0.75*N)
x_train,y_train = x[:N_train],y[:N_train]
x_test,y_test = x[N_train:],y[N_train:]
   
print(f"N={N}, N_train={N_train}, L={L}")
# Out:
# N=5000, N_train=3750, L=4

# %%
def scat(ax,x,y,i=0,j=1,s=4,title=""):
    ax.scatter(x[:,i],x[:,j],s=s,c=y)
    ax.set_xlabel(f"feature {i}")
    ax.set_ylabel(f"feature {j}")
    ax.set_title(title)

for n in range(5):
    print(x[n],y[n])

fig,AX = plt.subplots(2,2,figsize=(8.5,8.1))
scat(AX[0,0],x_train,y_train,title="Train")
scat(AX[0,1],x_train,y_train,i=2,j=3,title="Train")
scat(AX[1,0],x_test,y_test,title="Test")
scat(AX[1,1],x_test,y_test,i=2,j=3,title="Test")
fig.tight_layout()
plt.show()
# Out:
# [-31.608 -29.544   6.773   9.554] 0
# [46.451 15.318 24.891 15.357] 0
# [ 24.771  46.131 -49.161 -39.356] 0
# [-20.13   15.641  30.981  37.218] 0
# [46.465 22.369 14.248 21.745] 0

# %%
def classify(clf=GradientBoostingClassifier(),show=False, ffnn=False, title=None, show_tree=False, x_train = x_train, y_train = y_train, x_test = x_test, y_test = y_test):
    # GradientBoostingClassifier():
    #   n_estimators = 100 (default)
    #   loss function = deviance(default) used in Logistic Regression
    # XGBClassifier()
    #   n_estimators = 100 (default)
    #   max_depth = 3 (default?)
    clf.fit(x_train,y_train)
    y_hat = clf.predict(x_test)
    
    if ffnn:
        errors=(1-clf.evaluate(x_test, y_test)[-1])
        accuracy=clf.evaluate(x_test, y_test)[-1]
    else:
        errors=100*(1-clf.score(x_test, y_test))
        accuracy=clf.score(x_test, y_test)
    
    if show: print("errors: {:.2f}%   Accuracy={:.3f}".format(100*errors,accuracy))
    S=50
    dx = 1
    x_seq=np.arange(-S,S+dx,dx)
    nx = len(x_seq)
    x_plot=np.zeros((nx*nx,L))
    q=0
    for i in range(nx):
        for j in range(nx):
            x_plot[q,:2] = [x_seq[i],x_seq[j]]
            q+=1

    if show:
        y_plot= clf.predict(x_plot)
        fig,AX = plt.subplots(1,2,figsize=(8.2,4))
        if title != None:
            scat(AX[0],x_plot[:],y_plot,s=dx,title=title)
        else:
            scat(AX[0],x_plot[:],y_plot,s=dx,title="predicted")
            scat(AX[1],x_train[:],y_train,title="training set")
            fig.tight_layout()
        plt.show()
    
    if show_tree:      
        dump_list = clf.get_booster().get_dump()
        num_trees = len(dump_list)
        print("num_trees=",num_trees)
        
        fig, AX = plt.subplots(2,1,figsize=(12, 5))
        for i in range(min(2,num_trees)):
            ax=AX[i]
            plot_tree(clf, num_trees=i, ax=ax)
        fig.savefig("DATA/tree-classif.png", dpi=400, pad_inches=0.02)   
        plt.show()
        
    return errors,accuracy

# %% [markdown]
# ### Classify
# If the “objective” hyperparameter is left unspecified, XGBClassifier looks at the data and chooses automatically the loss functions and the evaluation metrics (--> WARNING)

# %% [markdown]
# ## XGBoost
# https://xgboost.readthedocs.io/en/stable/python/python_api.html

# %%
model = XGBClassifier(seed=1,
                      objective='binary:logistic',
                      importance_type="gain") #weight, cover, ...
       # learning_rate=0.4,
       # reg_lambda=0.001, 
       # n_estimators=30)

classify(model, show=True)
# Out:
# errors: 6.64%   Accuracy=0.934
# (0.06640000000000001, 0.9336)

# %%
# https://machinelearningmastery.com/feature-importance-and-feature-selection-with-xgboost-in-python/
# feature importance

print(model.importance_type)
print(model.feature_importances_)
# plot
my_cmap = plt.get_cmap("Reds")
rescale = lambda y: 0.3 + 0.7 * (y - np.min(y)) / (np.max(y) - np.min(y))
plt.bar(range(len(model.feature_importances_)), model.feature_importances_,
        color=my_cmap(rescale(model.feature_importances_)))
plt.xlabel("feature")
plt.ylabel("importance")
plt.xticks(np.arange(L))
plt.title(model.importance_type)
plt.show()

rescale_r = lambda y: 0.3 + 0.7 * (np.max(y) - y) / (np.max(y) - np.min(y))
plot_importance(model,color=my_cmap(rescale_r(model.feature_importances_)))
plt.show()
# Out:
# gain
# [0.41903338 0.44306126 0.06554136 0.07236399]

# %% [markdown]
# Documentation: https://xgboost.readthedocs.io/en/stable/python/python_api.html
#
#     ‘weight’: the number of times a feature is used to split the data across all trees.
#
#     ‘gain’: the average gain across all splits the feature is used in.
#
#     ‘cover’: the average coverage across all splits the feature is used in.
#
#     ‘total_gain’: the total gain across all splits the feature is used in.
#
#     ‘total_cover’: the total coverage across all splits the feature is used in.

# %%
# if the importance type is “total_gain”, then the score is sum of loss change for each split from all trees.
list_type=["weight","gain","total_gain","cover","total_cover"]
list_col=["#7565F0","k","#666666","#F0A000","gold"]

for i,t in enumerate(list_type):
    feature_imp = model.get_booster().get_score(importance_type=t)
    keys = list(feature_imp.keys())
    values = np.array(list(feature_imp.values()))
    print(i,t,values)
    values= values/np.sum(values)
    plt.bar(np.arange(L)+(i-L/2)/10, values,color=list_col[i],width=0.1,label=t)
plt.xlabel("feature")
plt.ylabel("importance (normalized to 1)")
plt.xticks(np.arange(L))
plt.legend()
plt.show()
# Out:
# 0 weight [1070. 1171.  335.  306.]
# 1 gain [3.84043288 4.06064796 0.6006853  0.66321456]
# 2 total_gain [4109.26318359 4755.01904297  201.22956848  202.94364929]
# 3 cover [73.71099854 66.86531067 77.84243011 62.61100388]
# 4 total_cover [78870.765625   78299.28125    26077.21289062 19158.96679688]

# %% [markdown]
# ## normal Gradient Boosting

# %%
# GradientBoostingClassifier()
classify()
# Out:
# (0.1976, 0.8024)

# %% [markdown]
# ## AdaBoost

# %%
classify(clf=AdaBoostClassifier(learning_rate=.8,n_estimators=150,algorithm="SAMME"))
# Out:
# (0.4072, 0.5928)

# %% [markdown]
# # 1. Model complexity, parameters’ and regularization

# %%
def make_and_test_xgb_model(importance_type="gain", learning_rate=0.4 ,reg_lambda=0.001, n_estimators=40, max_depth = 6, gamma = 0):
    model = XGBClassifier(seed=1,
                          objective='binary:logistic',
                          importance_type="gain",#weight, cover, ...
                          learning_rate=learning_rate,
                          reg_lambda=reg_lambda, 
                          n_estimators=n_estimators,
                          max_depth = max_depth,
                          gamma = gamma,
                          n_jobs = -1 )

    err, acc = classify(model)
    return model, acc, err

# %% [markdown]
# #### Test varying learning rate and n_range

# %%
n_range = np.linspace(10,200,40)
l_range = np.linspace(0.1,1,40)

acc_arr = []
for n in tqdm(n_range, desc = "Processing"):
    acc_row = []
    for l in l_range:
        model, acc, err = make_and_test_xgb_model(importance_type="gain", learning_rate=l ,reg_lambda=0.001, n_estimators=int(n), max_depth = 6, gamma = 0)
        acc_row.append(acc)
    acc_arr.append(acc_row)

f_name = f"Point_1/{float(min(l_range))},{float(max(l_range))},{min(n_range)},{max(n_range)}.npy"
np.save(f_name, acc_arr)
print("File", f_name, "saved correctly")
# Out:
# Processing: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 40/40 [02:55<00:00,  4.39s/it]
# File Point_1/0.1,1.0,10.0,200.0.npy saved correctly

# %% [markdown]
# Code to visualize the saved file

# %%
mi_n = 10
ma_n = 200
mi_l = 0.1
ma_l = 1.0

acc_arr_r = np.load(f"Point_1/{mi_l},{ma_l},{float(mi_n)},{float(ma_n)}.npy")

n_range = np.linspace(mi_n,ma_n,len(acc_arr_r), dtype="int")
l_range = np.linspace(mi_l,ma_l,len(acc_arr_r[0]))

max_idx = np.unravel_index(np.argmax(acc_arr_r), acc_arr_r.shape)
max_value = acc_arr_r[max_idx]

best_n_estimators = n_range[max_idx[0]]
best_learning_rate = l_range[max_idx[1]]

print(f"Best accuracy with n_estimators = {best_n_estimators} and learning rate = {best_learning_rate:.2f}")

plt.figure(figsize=(8, 6))
plt.imshow(acc_arr_r)
plt.colorbar(label="accuracy", shrink= 1)

plt.scatter(max_idx[1],max_idx[0], color = "r", label = f"max accuracy = {max_value}")

plt.xlabel("learning rate")
plt.ylabel("n. estimators")
plt.yticks(range(len(n_range)), labels=n_range)
plt.xticks(range(len(l_range)), labels=[f'{val:.2f}' for val in l_range], rotation = 90)
xticks = plt.xticks()[0] 
yticks = plt.yticks()[0]
plt.xticks(xticks[::3])
plt.yticks(yticks[::3])
plt.legend(loc = "best")

plt.show()
# Out:
# Best accuracy with n_estimators = 44 and learning rate = 0.38

# %% [markdown]
# #### Test varying gamma and reg_lambda
# We use the best combination founded for the learning rate and n_estimators

# %%
mi_g = 0
ma_g = 0.02
mi_la = 0.0001
ma_la = 0.005

g_range = np.linspace(mi_g,ma_g,40)
la_range = np.linspace(mi_la,ma_la,40)

acc_arr = []
for g in tqdm(g_range, desc = "Processing"):
    acc_row = []
    for la in la_range:
        model, acc, err = make_and_test_xgb_model(importance_type="gain", learning_rate=best_learning_rate ,reg_lambda=la, n_estimators=best_n_estimators, max_depth = 6, gamma = g)
        acc_row.append(acc)
    acc_arr.append(acc_row)

f_name = f"Point_1/{float(min(la_range))},{float(max(la_range))},{min(g_range)},{max(g_range)}_lambda_and_gamma.npy"
np.save(f_name, acc_arr)
print("File", f_name, "saved correctly")

# %%
acc_arr_r = np.load(f"Point_1/{float(mi_la)},{ma_la},{float(mi_g)},{float(ma_g)}_lambda_and_gamma.npy")

g_range = np.linspace(mi_g,ma_g,len(acc_arr_r))
la_range = np.linspace(mi_la,ma_la,len(acc_arr_r[0]))

max_idx = np.unravel_index(np.argmax(acc_arr_r), acc_arr_r.shape)
max_value = acc_arr_r[max_idx]

best_gamma = g_range[max_idx[0]]
best_lambda = la_range[max_idx[1]]

print(f"Best accuracy with n_estimators = {best_gamma} and learning rate = {best_lambda:.4f}")

plt.figure(figsize=(8, 6))
plt.imshow(acc_arr_r)
plt.colorbar(label="accuracy", shrink= 1)

plt.scatter(max_idx[1],max_idx[0], color = "r", label = f"max accuracy = {max_value}")

plt.xlabel("lambda reg.")
plt.ylabel("gamma")
plt.yticks(range(len(g_range)), labels=[f'{val:.4f}' for val in g_range])
plt.xticks(range(len(la_range)), labels=[f'{val:.4f}' for val in la_range], rotation = 90)
xticks = plt.xticks()[0] 
yticks = plt.yticks()[0]
plt.xticks(xticks[::3])
plt.yticks(yticks[::3])
plt.legend(loc = "best")

plt.show()
# Out:
# Best accuracy with n_estimators = 0.0 and learning rate = 0.0001

# %% [markdown]
# ### Searching randomly in the hyperparameter space around the best point founded in the previous steps

# %%
np.random.seed(1234)

def search(tra_test, n_test=10):

    "learning_rate=0.4 ,reg_lambda=0.001, n_estimators=40, max_depth = 6, gamma = 0"
    x = [np.array([best_learning_rate ,best_lambda, best_n_estimators, best_gamma])]
    model, acc,_ = tra_test(learning_rate=x[0][0] ,reg_lambda=x[0][1], n_estimators=int(x[0][2]), gamma = x[0][3])
    model_arr = [model]
    acc_arr = [acc]
    
    for i in tqdm(range(n_test), desc = "Processing"):
        model, acc, _ = tra_test(learning_rate=x[i][0] ,reg_lambda=x[i][1], n_estimators=int(x[i][2]), gamma = x[i][3])       
        model_arr.append(model)
        acc_arr.append(acc)
        x.append(np.array([max(0, best_learning_rate + (np.random.uniform()-0.5)*0.05),
                           max(0, best_lambda + (np.random.uniform()-0.5)*0.0005),
                           best_n_estimators + int((np.random.uniform()-0.5)*2),
                           max(0, best_gamma + (np.random.uniform()-0.5)*0.005)]))

    sorted_indices = np.argsort(acc_arr)[::-1]
    model_arr = np.array(model_arr)[sorted_indices]
    acc_arr = np.array(acc_arr)[sorted_indices]
    x = np.array(x)[sorted_indices] 
    return model_arr, acc_arr, x

# %%
model_arr, acc_arr, hyper_param = search(make_and_test_xgb_model, n_test = 1000)
# Out:
# Processing: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:50<00:00, 19.72it/s]

# %%
for i in range(5):
    print(f"{acc_arr[i]:.5f}", hyper_param[i])
# Out:
# 0.93680 [3.76923077e-01 1.00000000e-04 4.40000000e+01 0.00000000e+00]
# 0.93680 [4.00788710e-01 3.37698183e-04 4.40000000e+01 1.57494101e-03]
# 0.93680 [3.83617306e-01 4.55057491e-05 4.40000000e+01 6.54690354e-04]
# 0.93680 [3.61499049e-01 1.61054386e-04 4.40000000e+01 1.42679292e-03]
# 0.93520 [3.84056025e-01 1.75570120e-04 4.40000000e+01 0.00000000e+00]

# %% [markdown]
# For me the best model is this --> model_arr[0]

# %%
best_accuracy = acc_arr[0]
model = model_arr[0]
hyper_par = hyper_param[0]

# %% [markdown]
# # 2. Dimensionality reduction
# Now we want to observe how the training perform reducing the dimensionality of the feature space.

# %%
fig,AX = plt.subplots(1,2,figsize=(8.5,4.1))
scat(AX[0],x,y,title="Train")
scat(AX[1],x,y,i=2,j=3,title="Train")

fig.tight_layout()
plt.show()

# %% [markdown]
# Generate the training and the test set without one of the feature space dimension.

# %%
def remove_dim(dim, data = x):
    return np.delete(data, dim, axis = 1)

x_train_0 = remove_dim(0, data = x_train)
x_test_0 = remove_dim(0, data = x_test)
x_train_1 = remove_dim(1, data = x_train)
x_test_1 = remove_dim(1, data = x_test)
x_train_2 = remove_dim(2, data = x_train)
x_test_2 = remove_dim(2, data = x_test)
x_train_3 = remove_dim(3, data = x_train)
x_test_3 = remove_dim(3, data = x_test)

x_train_arr = [x_train_0, x_train_1, x_train_2, x_train_3]
x_test_arr = [x_test_0, x_test_1, x_test_2, x_test_3]

# %%
acc_perf_without_feature = [best_accuracy]

for tr,te in zip(x_train_arr, x_test_arr):
    _, acc = classify(model, x_train = tr, x_test = te)
    acc_perf_without_feature.append(acc)

x_labels = ["All f.", "No f. 1", "No f. 2", "No f. 3", "No f. 4"]

plt.scatter(x_labels, acc_perf_without_feature, zorder = 2)
plt.xlabel("")
plt.ylabel("Accuracy")
plt.grid(zorder = 0)

plt.show()

# %% [markdown]
# As expected removing the first or the second feature of the data results in a sensible worst accuracy respect to the one obtained in the full data case.\
# Removing the third or the forth instead slightly change the performance of the model resulting in an accuracy comparable with the original one.
#
# We now exploit the results obtained removing both the third and the forth dimensions.

# %%
x_train_23 = remove_dim(3, data = x_train)
x_test_23 = remove_dim(3, data = x_test)
x_train_23 = remove_dim(2, data = x_train_23)
x_test_23 = remove_dim(2, data = x_test_23)

_, acc = classify(model, x_train = x_train_23, x_test = x_test_23)

acc_compl = np.copy(acc_perf_without_feature)
acc_compl = np.append(acc_compl, acc)

x_labels = ["All f.", "No f. 1", "No f. 2", "No f. 3", "No f. 4", "No f. 3&4"]

plt.scatter(x_labels, acc_compl, zorder = 2)
plt.xlabel("")
plt.ylabel("Accuracy")
plt.grid(zorder = 0)

plt.show()

print("\nThe accuracy with the entire dataset is:", best_accuracy,"while the accuracy obtained removing the two last dimensions is:", f"{acc:.4f}")
# Out:
# The accuracy with the entire dataset is: 0.9368 while the accuracy obtained removing the two last dimensions is: 0.9360

# %% [markdown]
# # XGBoost vs NN

# %% [markdown]
# # Neural Network

# %%
def create_model(optimizer='sgd', activation ='elu', neurons = 20):
    model = keras.Sequential()
    #model.add(layers.Input(shape=(L,))
    model.add(layers.Dense(L,input_shape=(L,), activation=activation))
    model.add(layers.Dense(neurons, activation=activation))
    model.add(layers.Dense(neurons, activation=activation))
    model.add(layers.Dense(neurons, activation=activation))
    model.add(layers.Dropout(0.01))
    model.add(layers.Dense(1,activation='sigmoid'))
    nepoch=20
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# %%
import os
#to disable GPU, otherwise I've got some errors
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3" 

#import tensorflow.random as tf_r
#tf_r.set_seed(2072050)

# create model
model = KerasClassifier(model=create_model, epochs=20, batch_size=50, verbose=0)

# define the grid search parameters
optimizer = ['SGD', 'RMSprop', 'Adam']
activation = [ 'sigmoid','relu','elu']
neurons = [10,15,20]
param_grid = dict(model__optimizer=optimizer, model__activation = activation, model__neurons = neurons)

# actual gridsearch
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(x_train, y_train)

# saving info about gridsearch results in a dataframe in descending order of accuracy
results_DNN = pd.concat([pd.DataFrame(grid.cv_results_["params"]),
                     pd.DataFrame(grid.cv_results_["mean_test_score"], columns=["Accuracy"])],axis=1)
results_DNN = results_DNN.sort_values(by=['Accuracy'], ascending = False)
results_DNN = results_DNN.reset_index(drop=True)
print("the best performing combinations of parameters for DNN (from highest to lowest accuracy): ")
results_DNN.head()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743234300.554459  261326 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743234300.562240  261326 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1743234300.582975  261326 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.583105  261326 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.583161  261326 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.583193  261326 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743234300.672327  261329 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743234300.680782  261329 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1743234300.702246  261329 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.702362  261329 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.702390  261329 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.702414  261329 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743234300.753729  261328 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743234300.761751  261328 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743234300.766000  261332 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743234300.781139  261332 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1743234300.783648  261328 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.783767  261328 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.783807  261328 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.783835  261328 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743234300.795844  261335 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743234300.805845  261335 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1743234300.809966  261332 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.810077  261332 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.810103  261332 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.810123  261332 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.828953  261335 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.829068  261335 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.829100  261335 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.829120  261335 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743234300.836631  261337 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743234300.845215  261337 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1743234300.867048  261337 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.867159  261337 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.867187  261337 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.867208  261337 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743234300.888356  261340 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743234300.897543  261340 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743234300.903866  261341 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743234300.912568  261341 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1743234300.919865  261340 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.919979  261340 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.920020  261340 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.920055  261340 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.933942  261341 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.934055  261341 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.934091  261341 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.934117  261341 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743234300.941553  261342 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743234300.950280  261342 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743234300.963778  261339 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# W0000 00:00:1743234300.972154  261342 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.972323  261342 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.972329  261342 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.972332  261342 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# E0000 00:00:1743234300.973248  261339 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1743234300.995152  261339 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.995255  261339 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.995316  261339 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234300.995352  261339 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743234301.047313  261343 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743234301.057291  261343 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743234301.077283  261336 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# W0000 00:00:1743234301.083916  261343 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234301.084017  261343 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234301.084043  261343 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234301.084064  261343 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# E0000 00:00:1743234301.086493  261336 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1743234301.111168  261336 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234301.111330  261336 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743234301.111292  261330 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# W0000 00:00:1743234301.111412  261336 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234301.111446  261336 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# E0000 00:00:1743234301.123478  261330 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1743234301.151767  261330 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234301.151920  261330 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234301.151972  261330 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234301.152015  261330 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743234301.172406  261334 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743234301.183202  261334 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743234301.195127  261333 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743234301.206128  261333 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1743234301.209944  261334 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234301.210075  261334 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234301.210131  261334 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234301.210176  261334 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234301.237180  261333 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234301.237377  261333 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234301.237464  261333 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234301.237541  261333 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743234301.342104  261338 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743234301.353509  261338 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1743234301.382363  261338 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234301.382416  261338 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234301.382424  261338 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743234301.382429  261338 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e0f50526520> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e0f50526520> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7439cc4976a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x763004737ba0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x725f8861ff60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7439cc4976a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x763004737ba0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x725f8861ff60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x74be10583ba0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x74be10583ba0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b080c706980> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b080c706980> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x735748534680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x74a908322020> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x735748534680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x73c5e818b2e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x73c5e818b2e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x72a568412980> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x72a568412980> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e46b03047c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e46b03047c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d17143372e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d17143372e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x70d550457100> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x70d550457100> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/marco/anaconda3/lib/python3.12/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# /home/marco/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# the best performing combinations of parameters for DNN (from highest to lowest accuracy):
#   model__activation  model__neurons model__optimizer  Accuracy
# 0              relu              15          RMSprop  0.591844
# 1           sigmoid              20              SGD  0.576018
# 2           sigmoid              10          RMSprop  0.576018
# 3           sigmoid              20             Adam  0.576018
# 4           sigmoid              20          RMSprop  0.576018

# %%
print('the optimal activation function for DNN is: ',results_DNN['model__activation'][0])
print('the optimal number of neurons for DNN hidden layer is: ',results_DNN['model__neurons'][0])
print('the optimal optimizer for DNN is: ',results_DNN['model__optimizer'][0])
# Out:
# the optimal activation function for DNN is:  relu
# the optimal number of neurons for DNN hidden layer is:  15
# the optimal optimizer for DNN is:  RMSprop

# %% [markdown]
# # For XGBoost

# %%
# create model
estimator = XGBClassifier( objective= 'binary:logistic', nthread=4, seed=42)

# define the grid search parameters
parameters = { 'reg_lambda': [1, 10,50], 
              'gamma': [0,0.01,0.1,0.2,0.5],
              'n_estimators': range(60, 220, 40)  }

# actual gridsearch
grid_search = GridSearchCV(estimator=estimator, param_grid=parameters, scoring = 'roc_auc', n_jobs = 10,cv = 10,verbose=0)
grid_result = grid_search.fit(x_train, y_train)

# saving info about gridsearch results in a dataframe in descending order of accuracy
results = pd.concat([pd.DataFrame(grid_search.cv_results_["params"]),
                     pd.DataFrame(grid_search.cv_results_["mean_test_score"], columns=["Accuracy"])],axis=1)
results_xgb = results.sort_values(by=['Accuracy'], ascending = False)
results_xgb = results_xgb.reset_index(drop=True)
print("the best performing combinations of parameters are (from highest to lowest accuracy): ")
(results_xgb).head()
# Out:
# the best performing combinations of parameters are (from highest to lowest accuracy):
#    gamma  n_estimators  reg_lambda  Accuracy
# 0   0.00           100           1  0.732051
# 1   0.01           180           1  0.731410
# 2   0.00            60           1  0.728205
# 3   0.00           140           1  0.728205
# 4   0.01            60           1  0.727564

# %%
print('the optimal number of estimators is: ',results_xgb['n_estimators'][0])
print('the optimal value of parameter lambda is: ',results_xgb['reg_lambda'][0])
print('the optimal value of parameter gamma is: ',results_xgb['gamma'][0])
# Out:
# the optimal number of estimators is:  100
# the optimal value of parameter lambda is:  1
# the optimal value of parameter gamma is:  0.0

# %% [markdown]
# # Compare the results

# %%
model = create_model(optimizer='sgd', activation ='elu', neurons = 20)
classify(model, show=True, ffnn=True)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4910 - loss: 0.9491
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 2
#       1 model = create_model(optimizer='sgd', activation ='elu', neurons = 20)
# ----> 2 classify(model, show=True, ffnn=True)
#
# Cell In[27], line 9, in classify(clf, show, ffnn, title, show_tree, x_train, y_train, x_test, y_test)
#       1 def classify(clf=GradientBoostingClassifier(),show=False, ffnn=False, title=None, show_tree=False, x_train = x_train, y_train = y_train, x_test = x_test, y_test = y_test):
#       2     # GradientBoostingClassifier():
#       3     #   n_estimators = 100 (default)
#    (...)
#       6     #   n_estimators = 100 (default)
#       7     #   max_depth = 3 (default?)
#       8     clf.fit(x_train,y_train)
# ----> 9     y_hat = clf.predict(x_test)
#      11     if ffnn:
#      12         errors=(1-clf.evaluate(x_test, y_test)[-1])
#
# File ~/anaconda3/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/anaconda3/lib/python3.12/site-packages/keras/src/utils/progbar.py:119, in Progbar.update(self, current, values, finalize)
#     116     message += "\n"
#     118 if self.target is not None:
# --> 119     numdigits = int(math.log10(self.target)) + 1
#     120     bar = ("%" + str(numdigits) + "d/%d") % (current, self.target)
#     121     bar = f"\x1b{bar}\x1b "
#
# ValueError: math domain error

# %%
size = np.array([500,1000,2000,1000])
acc_DNN = np.zeros(5)
acc_XGBC = np.zeros(5)

for idx,i in enumerate(size):
    X,Y = shuffle(x,y)
    X = X[:i-1]
    Y = Y[:i-1]

    N_train = int(i/2)
    N_test  = i - N_train 
    
    x_train,y_train = X[:N_train],Y[:N_train]
    x_test,y_test = X[(N_train-1):],Y[(N_train-1):]
    L=len(x_train[0])
    model = create_model(optimizer= results_DNN['model__optimizer'][0], activation = results_DNN['model__activation'][0], 
                         neurons=results_DNN['model__neurons'][0]) 
        
    _, acc_DNN[idx]  = classify(clf=model, show = True, ffnn=True)#, title = f"DNN with {N_train} training data")
    # _, acc_XGBC[idx] = classify(XGBClassifier(seed=1, objective='binary:logistic',
    #                    reg_lambda = results_xgb['reg_lambda'][0], 
    #                    n_estimators = results_xgb['n_estimators'][0],
    #                    gamma = results_xgb['gamma'][0] ), show=True)#, title = f"XGBoost with {N_train} training data")
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5133 - loss: 0.8405
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 19
#      15 L=len(x_train[0])
#      16 model = create_model(optimizer= results_DNN['model__optimizer'][0], activation = results_DNN['model__activation'][0],
#      17                      neurons=results_DNN['model__neurons'][0])
# ---> 19 _, acc_DNN[idx]  = classify(clf=model, show = True, ffnn=True)
#
# Cell In[27], line 9, in classify(clf, show, ffnn, title, show_tree, x_train, y_train, x_test, y_test)
#       1 def classify(clf=GradientBoostingClassifier(),show=False, ffnn=False, title=None, show_tree=False, x_train = x_train, y_train = y_train, x_test = x_test, y_test = y_test):
#       2     # GradientBoostingClassifier():
#       3     #   n_estimators = 100 (default)
#    (...)
#       6     #   n_estimators = 100 (default)
#       7     #   max_depth = 3 (default?)
#       8     clf.fit(x_train,y_train)
# ----> 9     y_hat = clf.predict(x_test)
#      11     if ffnn:
#      12         errors=(1-clf.evaluate(x_test, y_test)[-1])
#
# File ~/anaconda3/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/anaconda3/lib/python3.12/site-packages/keras/src/utils/progbar.py:119, in Progbar.update(self, current, values, finalize)
#     116     message += "\n"
#     118 if self.target is not None:
# --> 119     numdigits = int(math.log10(self.target)) + 1
#     120     bar = ("%" + str(numdigits) + "d/%d") % (current, self.target)
#     121     bar = f"\x1b{bar}\x1b "
#
# ValueError: math domain error

# %%
size = np.array([500,1000,5000,10000,20000])
fig, ax= plt.subplots()
ax.plot(size, acc_DNN, label='DNN')
ax.plot(size, acc_XGBC, label='XGB_Classifier')
ax.set_xlabel('size of dataset')
ax.set_ylabel('accuracy')
ax.set_xlim(np.min(size),np.max(size))
ax.locator_params(axis='x', nbins=5)
ax.grid()
ax.legend()

# %% [markdown]
# ## TENTATIVO RIPRENDENDO NOSTRO VECCHIO NOTEBOOK SU N.N.

# %%
# Fraction dataset used as training
fractions = np.arange(0.25,0.80,0.05)
fractions
# Out:
# array([0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 , 0.55, 0.6 , 0.65, 0.7 , 0.75])

# %%
# Fuction to build a FFNN
def build_ffnn( hp ):
    model = keras.Sequential()
    model.add(layers.Dense(L,input_shape=(L,),activation='relu'))
    # Tune the number of layers of the model
    for i in range(hp.Int("num_layers", 1, 6)):
        #print(f"Adding hidden layer {i} with {hp.Int(f'units_{i}', 10, 30, step=5)} units")  # Debug print
        model.add(layers.Dense(
                #Define the units and the activation functions
                units=hp.Int(f"units_{i}", min_value=10, max_value=30, step=5),
                activation=hp.Choice("activation", ["relu", "sigmoid", "tanh", "elu"]),
            )
        )
        #Define the dropout values of the model
        model.add(layers.Dropout(rate=hp.Float("dropout", min_value = 0, max_value = 0.2, step = 0.05)))
    #Output layer is composed by 1 neuron since it's classification task
    model.add(layers.Dense(1, activation="sigmoid"))
    #Define the learning rate of the model
    learning_rate = hp.Float("lr", min_value=1e-6, max_value=1e-1, sampling="log")
    model.compile(
        #Define the optimizers of the model
        optimizer=hp.Choice("optimizer", ["adam", "RMSprop", "SGD"]), loss="binary_crossentropy",
        metrics=["accuracy"])
    return model
    

#After builiding the model we impose the tuning
tuner = keras_tuner.RandomSearch(
    hypermodel = build_ffnn,
    objective = "val_accuracy",
    max_trials = 4,
    executions_per_trial = 1,
    overwrite = True,
)

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 6
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 6, 'step': 1, 'sampling': 'linear'}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 10, 'max_value': 30, 'step': 5, 'sampling': 'linear'}
# activation (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'sigmoid', 'tanh', 'elu'], 'ordered': False}
# dropout (Float)
# {'default': 0.0, 'conditions': [], 'min_value': 0.0, 'max_value': 0.2, 'step': 0.05, 'sampling': 'linear'}
# lr (Float)
# {'default': 1e-06, 'conditions': [], 'min_value': 1e-06, 'max_value': 0.1, 'step': None, 'sampling': 'log'}
# optimizer (Choice)
# {'default': 'adam', 'conditions': [], 'values': ['adam', 'RMSprop', 'SGD'], 'ordered': False}

# %%
nEpochs = 100
tuner.search(x_train, y_train, batch_size = 50, epochs = nEpochs, validation_data=(x_test, y_test), verbose=0)

# %%
# Printing out the 4 best models found by the keras tuner
tuner.results_summary(num_trials=3)
# Out:
# Results summary
# Results in ./untitled_project
# Showing 3 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 2 summary
# Hyperparameters:
# num_layers: 5
# units_0: 10
# activation: elu
# dropout: 0.0
# lr: 2.3072842524072937e-05
# optimizer: SGD
# units_1: 15
# units_2: 20
# units_3: 30
# units_4: 10
# units_5: 25
# Score: 0.5600000023841858
#
# Trial 0 summary
# Hyperparameters:
# num_layers: 6
# units_0: 30
# activation: tanh
# dropout: 0.0
# lr: 2.0610853935613374e-05
# optimizer: adam
# units_1: 10
# units_2: 10
# units_3: 10
# units_4: 10
# units_5: 10
# Score: 0.5440000295639038
#
# Trial 3 summary
# Hyperparameters:
# num_layers: 5
# units_0: 30
# activation: relu
# dropout: 0.2
# lr: 0.003522845422883248
# optimizer: adam
# units_1: 15
# units_2: 15
# units_3: 15
# units_4: 10
# units_5: 30
# Score: 0.5239999890327454

# %%
#The tuner returns the model already trained, and we take the 4 best ones
modelsHyperParam = tuner.get_best_hyperparameters(num_trials = 4)
#To see the best hyparameters
#print(modelsHyperParam[0].values)

# To save hyperparameters
with open("best_hyperparameters.json", "w") as file:
    json.dump([hp.values for hp in modelsHyperParam], file, indent=4)

# %%
# To retrieve the per hyperparameters from the keras_tuner search
#with open("best_hyperparameters.json", 'r') as file:
#    modelsHyperParam = json.load(file)

# %%
np.random.seed(12345)

dname="./DATA/"
str0="_XGB_25.dat"
fnamex=dname+'x'+str0
fnamey=dname+'y'+str0
x = np.loadtxt(fnamex, delimiter=" ",dtype=float)
y = np.loadtxt(fnamey)
y = y.astype(int)
N,L = len(x), len(x[0])

N_train = int(0.75*N)
x_train,y_train = x[:N_train],y[:N_train]
x_test,y_test = x[N_train:],y[N_train:]
   
print(f"N={N}, N_train={N_train}, L={L}")
# Out:
# N=5000, N_train=3750, L=4

# %%
model = build_ffnn(modelsHyperParam[0])
classify(model, show=True, ffnn=True, x_train=x_train, y_train=y_train, x_test = x_test, y_test = y_test)
# Out:
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4996 - loss: 0.8398
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5504 - loss: 0.6918
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5504 - loss: 0.6918
# errors: 46.24%   Accuracy=0.538
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# (0.46240001916885376, 0.5375999808311462)

# %%
def PlotAccuracyAndLoss(fit):

    fig, AX = plt.subplots(1, 2, figsize = (16,8))

    fig.suptitle(f"Performance of the best FFNN")

    ax = AX[0]
    ax.plot(fit.history['accuracy'], label="train", c="b", ls="--")
    ax.plot(fit.history['val_accuracy'], label="valid.", c="r")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Accuracy")
    ax.legend()

    ax = AX[1]
    ax.plot(fit.history['loss'],label="train",c="b",ls="--")
    ax.plot(fit.history['val_loss'],label="valid.",c="r")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Loss")
    ax.legend()

    plt.show()

# %%
fit = model.fit(x_train, y_train, epochs=100, batch_size=16, validation_data = (x_test,y_test), verbose=0)

# %%
PlotAccuracyAndLoss(fit)

# %%
for frac in fractions:
    N_train = int(frac * len(x))
    x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=N_train, shuffle=True, random_state=5205) #random_state=5205 is like the seed

# %%
# cross valitation of the ffnn
def cross_validate_ffnn(x_train, y_train, best_params):
    model = build_model(modelsHyperParam)
    kfold = KFold(n_splits=5, shuffle=True, random_state=42)
    train_accuracy = []
    val_accuracy   = []
    train_loss     = []
    val_loss       = []
    
    for train_idx, val_idx in kfold.split(x_train, y_train):
        model = build_model(modelsHyperParam)
        fit_kfold = model.fit(x_train[train_idx], y_train[train_idx], validation_data = (x_train[val_idx],y_train[val_idx]), epochs=100, batch_size=16, verbose=0)

        train_accuracy.append( fit_kfold.history['accuracy'] )
        val_accuracy.append  ( val_accuracy   + fit_kfold.history['val_accuracy'] )
        train_loss.append    ( train_loss     + fit_kfold.history['loss'] )
        val_loss.append      ( val_loss       + fit_kfold.history['val_loss'] )

    return np.mean(train_accuracy,axis=0), np.std(train_accuracy,axis=0), np.mean(val_accuracy,axis=0), np.std(val_accuracy,axis=0)

# %%
'''
fig, AX = plt.subplots(1, 2, figsize = (12,6))
fig.suptitle(f"Performance of the model N°{i+1}")

ax = AX[0]
#plt.errorbar(x, y, yerr=y_error,

ax.plot(train_accuracy[i], label="train" , c="b", ls="--")
ax.plot(val_accuracy[i]  , label="valid.", c="r")
ax.set_xlabel('epoch')
ax.set_ylabel("Accuracy")
ax.legend()

ax = AX[1]
ax.plot(train_loss[i],label="train" ,c="b",ls="--")
ax.plot(val_loss[i]  ,label="valid.",c="r")
ax.set_xlabel('epoch')
ax.set_ylabel("Loss")
ax.legend()

fig.tight_layout()
plt.show()
'''

# %%
# Funzione per validazione con cross-validation
def cross_validate_xgb(x_train, y_train):
    model = xgboost.XGBClassifier(eval_metric='logloss')
    scores = cross_val_score(model, x_train, y_train, cv=5, scoring='accuracy')
    return np.mean(scores), scores

# Hyperparameter Tuning per XGBoost
def tune_xgb(x_train, y_train):
    param_grid = {
        'n_estimators': [50, 100, 200],
        'max_depth': [3, 5, 7],
        'learning_rate': [0.01, 0.1, 0.2]
    }
    grid_search = GridSearchCV(xgboost.XGBClassifier(eval_metric='logloss'), param_grid, cv=5, scoring='accuracy')
    grid_search.fit(x_train, y_train)
    return grid_search.best_params_, grid_search.best_score_, pd.DataFrame(grid_search.cv_results_)

# %%
# Confronto XGBoost vs FFNN con cross-validation e tuning
results = []
all_xgb_results = []

for frac in tqdm(fractions):
    N_train = int(frac * len(x))
    x_train_cross, x_valid, y_train_cross, y_valid = train_test_split(x, y, train_size=N_train, stratify=y, random_state=42)
    
    acc_xgb, scores_xgb = cross_validate_xgb(x_train_cross, y_train_cross)
    best_ffnn_params, best_ffnn_score = tune_ffnn(x_train_cross, y_train_cross)
    acc_ffnn, scores_ffnn = cross_validate_ffnn(x_train_cross, y_train_cross, best_ffnn_params)
    best_xgb_params, best_xgb_score, xgb_cv_results = tune_xgb(x_train_cross, y_train_cross)
    all_xgb_results.append(xgb_cv_results)
    
    # Test di significatività
    #t_stat, p_value = ttest_ind(scores_xgb, scores_ffnn, equal_var=False)
    
    results.append((frac, acc_xgb, acc_ffnn, p_value, best_xgb_params, best_xgb_score, best_ffnn_params, best_ffnn_score))

# %%
# Visualizzazione dei risultati
fractions_plot = [r[0] for r in results]
acc_xgb_plot = [r[1] for r in results]
acc_ffnn_plot = [r[2] for r in results]

plt.figure(figsize=(8, 5))
plt.plot(fractions_plot, acc_xgb_plot, marker='o', label='XGBoost')
plt.plot(fractions_plot, acc_ffnn_plot, marker='s', label='FFNN')
plt.xlabel("Training Fraction")
plt.ylabel("Cross-Validated Accuracy")
plt.title("XGBoost vs FFNN Performance with Cross-Validation and Hyperparameter Tuning")
plt.legend()
plt.grid()
plt.show()

# Stampare i risultati
for frac, acc_xgb, acc_ffnn, p_value, best_xgb_params, best_xgb_score, best_ffnn_params, best_ffnn_score in results:
    print(f"Training fraction: {frac:.2f} | XGB CV Acc: {acc_xgb:.3f} | FFNN CV Acc: {acc_ffnn:.3f} | p-value: {p_value:.5f}")
    print(f"Best XGBoost params: {best_xgb_params} | Best XGB CV Score: {best_xgb_score:.3f}")
    print(f"Best FFNN params: {best_ffnn_params} | Best FFNN CV Score: {best_ffnn_score:.3f}\n")
